# %%
cat={'incm':'소득 4분위수(개인)', 'cfam':'가구원수', 'marri_1':'결혼여부', 'marri_2': "결혼상태", 'D_1_1':'주관적 건강상태', 
     'D_2_1': '최근2주간 몸이 불편했던 경험 유무', 'DI1_dg':'고혈압 의사진단 여부', 'DI1_pt':'고혈압 치료','DI1_2':'혈압조절제 복용',  'DI2_dg':'이상지질혈증 의사진단 여부',
    'DI2_pt':'이상지질혈증 치료', 'DI2_2':'이상지질혈증 약복용', 'DI3_dg':'뇌졸중 의사진단 여부', 'DI4_dg': "심근경색증 또는 협심증 의사진단 여부",
    'DM2_dg':'골관절염 의사진단 여부', 'DM4_dg':'골다공증 의사진단 여부', 'DJ2_dg':'폐결핵 의사진단 여부', 'DJ4_dg':'천식 의사진단 여부',
     'DE1_dg':'당뇨병 의사진단 여부', 'DE2_dg':'갑상선 질환 의사진단 여부', 'DC1_dg':'위암 의사진단 여부', 'DC2_dg':'간암 의사진단 여부',
     'DC3_dg':'대장암 의사진단 여부', 'DC4_dg':'유방암 의사진단 여부', 'DC5_dg':'자궁경부암 의사진단 여부', 'DF2_dg':'우울증 의사진단 여부',
     'DL1_dg':'아토피피부염 의사진단 여부', 'DJ8_dg':'알레르기비염 의사진단 여부', 'DJ6_dg':'부비동염 의사진단 여부', 'DH4_dg':'중이염 의사진단 여부', 
     'DH2_dg':'백내장 의사진단 여부', 'DH3_dg':'녹내장 의사진단 여부', 'DN1_dg':'신부전 의사진단 여부', 'DK8_dg':'B형간염 의사진단 여부',
     'DK9_dg':'C형간염 의사진단 여부', 'DK4_dg':'간경변증 의사진단 여부', 'BH1':'(성인) 건강검진 수진여부', 'BH1_1':'(성인) 건강검진 _본인부담종합', 
     'BH1_2':'(성인) 건강검진 _산업장특수1)', 'BH1_3':'(성인) 건강검진 _건강보험', 'BH1_8':'(성인) 건강검진 _무료건강검진', 'LQ1_sb':'최근 1달간 와병여부',
     'LQ3_sb':'최근 1년간 와병여부', 'LQ_1EQL':'EuroQoL : 운동능력', 'LQ_2EQL':'EuroQoL : 자기관리', 'LQ_3EQL':'EuroQoL : 일상활동',
     'LQ_4EQL':'EuroQoL : 통증/불편', 'LQ_5EQL':'EuroQoL : 불안/우울', 'educ':'교육수준 - 학력', 'EC1_1':'경제활동 상태', 'EC_stt_1':'종사상지위', 
     'EC_stt_2':'종사상지위_임금근로자 상세', 'EC_wh':'근로시간제', 'EC_wht_0':'정규직 여부', 'EC_wht_5':'변형근로시간', 'EC_lgw_2':'최장일자리: 표준직업분류', 
     'BO1':'주관적 체형인식', 'BO1_1':'1년간 체중 변화 여부', 'BO1_2':'1년간 체중 감소량', 'BO1_3':'1년간 체중 증가량', 'BO2_1':'1년간 체중 조절 여부',
     'BO3_01':'체중조절방법: 운동', 'BO3_02':'체중조절방법: 단식(24시간이상)', 'BO3_03':'체중조절방법: 식사량 감소', 'BO3_14':'체중조절방법: 결식(식사를 거름)',
     'BO3_05':'체중조절방법: 임의 체중감량제', 'BO3_04':'체중조절방법: 처방된 체중감량제', 'BO3_12':'체중조절방법: 한약복용', 'BD1':'평생음주경험',
     'BD1_11':'1년간 음주빈도', 'BD2_1':'한번에 마시는 음주량', 'BD2_31':'폭음 빈도', 'BP1':'평소 스트레스 인지 정도', 
     'BP6_10':'1년간 자살 생각 여부', 'BP6_2':'1년간 자살 계획 여부', 'mh_stress':'스트레스 인지율', 'BS1_1':'평생흡연 여부', 'BS2_1':'흡연 시작연령', 
     'BS2_2':'매일 흡연 시작연령', 'BS3_1':'현재흡연 여부', 'BS5_1':'(성인) 1개월내 금연계획', 'BE3_71':'일_고강도 신체활동 여부',
     'BE3_81':'일_중강도 신체활동 여부', 'BE3_91':'장소이동 신체활동 여부', 'BE3_75':'여가_고강도 신체활동 여부', 'BE3_85':'여가_중강도 신체활동 여부',
     'BE3_31':'1주일간 걷기 일수', 'BE5_1':'1주일간 근력운동 일수', 'BE9':'하루 60분 이상 신체활동 실천 일수', 'pa_aerobic':'유산소 신체활동 실천율',
     'LK_EDU':'영양교육 여부', 'LK_LB_CO':'영양표시 인지여부', 'LK_LB_US':'영양표시 이용여부','FS_MEAL':'하루 섭취 끼니 수'}

cont={'age':'만나이', 'D_2_wk':'최근2주간 불편감일수', 'LQ1_mn':'최근 1달간 와병일수', 'LQ3_mn':'최근 1년간 와병일수',
      'BD2':'음주 시작 연령', 'EC_wht_23':'주당 평균 근로시간', 'BD2_14':'한번에 마시는 음주량_잔', 'BP16_11':'주중 잠자리에 든 시각_시',
      'BP16_13':'주중 일어난 시각_시', 'BP16_21':'주말 잠자리에 든 시각_시', 'BP16_23':'주말 일어난 시각_시', 'Total_slp_wk':'주중 하루 평균 수면시간',
      'Total_slp_wd':'주말 하루 평균 수면시간', 'BS3_2':'하루평균 흡연량', 'BE3_72':'일_고강도 신체활동 일수', 'BE3_73':'일_고강도 신체활동 시간(시간)',
      'BE3_82':'일_중강도 신체활동 일수', 'BE3_83':'일_중강도 신체활동 시간(시간)', 'BE3_92':'장소이동 신체활동 일수', 'BE3_93':'장소이동 신체활동 시간(시간)',
      'BE3_76':'여가_고강도 신체활동 일수', 'BE3_77':'여가_고강도 신체활동 시간(시간)', 'BE3_86':'여가_중강도 신체활동 일수', 'BE3_87':'여가_중강도 신체활동 시간(시간)',
      'BE8_1':'평소 하루 앉아서 보내는 시간(시간)', 'BE3_32':'걷기 지속 시간(시간)', 'HE_fst':'공복시간', 'HE_ht':'신장', 'HE_wt':'체중'}


#식품조사부터는 안했음

# %%
from analysis import analysis_cat, analysis_cont
import pandas as pd

# %%
df=pd.read_csv('hn13-18_all_labeled.csv')
col=df.columns
col
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'ID', 'ID_fam', 'year', 'region',
#        'town_t', 'apt_t', 'psu', 'sex',
#        ...
#        'N_VA', 'N_CAROT', 'N_RETIN', 'N_B1', 'N_B2', 'N_NIAC', 'N_VITC',
#        'LF_secur_y', 'LF_BUYER', 'Ms'],
#       dtype='object', length=521)

# %%
non_cat=[]
for cat_var in cat:
    try:
        if(cat_var in col):
            print("변수 :",cat[cat_var])
            print('\n')
            analysis_cat(cat_var)
            print("--------------------------------------------------------\n")
        else:
            non_cat.append({cat_var:cat[cat_var]})
            
    except:
        pass
# Out:
# 변수 : 소득 4분위수(개인)
#
#
# number of values
# 대사증후군:	 [2056, 1916, 1799, 1682]
# 대사증후군:	 [8551, 8925, 9102, 9160]
# percent of values
# 대사증후군:	0.276%
# 대사증후군X:	0.239%
#
#
# 대사증후군:	0.257%
# 대사증후군X:	0.250%
#
#
# 대사증후군:	0.241%
# 대사증후군X:	0.255%
#
#
# 대사증후군:	0.226%
# 대사증후군X:	0.256%
#
#
# p-value= 1.8731486854202435e-13
# 유의미
# --------------------------------------------------------
#
# 변수 : 가구원수
#
#
# number of values
# 대사증후군:	 [1025, 2539, 1659, 1557, 539, 175]
# 대사증후군:	 [3237, 8949, 9060, 10407, 3174, 1055]
# percent of values
# 대사증후군:	0.137%
# 대사증후군X:	0.090%
#
#
# 대사증후군:	0.339%
# 대사증후군X:	0.249%
#
#
# 대사증후군:	0.221%
# 대사증후군X:	0.252%
#
#
# 대사증후군:	0.208%
# 대사증후군X:	0.290%
#
#
# 대사증후군:	0.072%
# 대사증후군X:	0.088%
#
#
# 대사증후군:	0.023%
# 대사증후군X:	0.029%
#
#
# p-value= 6.8883438014491205e-112
# 유의미
# --------------------------------------------------------
#
# 변수 : 결혼여부
#
#
# number of values
# 대사증후군:	 [6781, 713]
# 대사증후군:	 [25962, 9916]
# percent of values
# 대사증후군:	0.905%
# 대사증후군X:	0.724%
#
#
# ...

# %%
non_cat
# Out:
# [{'DM4_dg': '골다공증 의사진단 여부'},
#  {'DJ6_dg': '부비동염 의사진단 여부'},
#  {'DH4_dg': '중이염 의사진단 여부'},
#  {'DH2_dg': '백내장 의사진단 여부'},
#  {'DH3_dg': '녹내장 의사진단 여부'},
#  {'BH1_1': '(성인) 건강검진 _본인부담종합'},
#  {'BH1_2': '(성인) 건강검진 _산업장특수1)'},
#  {'BH1_3': '(성인) 건강검진 _건강보험'},
#  {'BH1_8': '(성인) 건강검진 _무료건강검진'},
#  {'LQ3_sb': '최근 1년간 와병여부'},
#  {'EC_wh': '근로시간제'},
#  {'BS2_1': '흡연 시작연령'},
#  {'BS2_2': '매일 흡연 시작연령'},
#  {'BE3_71': '일_고강도 신체활동 여부'},
#  {'BE3_81': '일_중강도 신체활동 여부'},
#  {'BE3_91': '장소이동 신체활동 여부'},
#  {'BE3_75': '여가_고강도 신체활동 여부'},
#  {'BE3_85': '여가_중강도 신체활동 여부'},
#  {'BE9': '하루 60분 이상 신체활동 실천 일수'},
#  {'pa_aerobic': '유산소 신체활동 실천율'},
#  {'FS_MEAL': '하루 섭취 끼니 수'}]

# %%
non_cont=[]

for cont_var in cont:
    try:
        if(cont_var in col):
            print("변수 :",cont[cont_var])
            print('\n')
            analysis_cont(cont_var)
            print("--------------------------------------------------------\n")
        else:
            non_cont.append({cont_var:cont[cont_var]})
        
    except:
        pass
# Out:
# 변수 : 만나이
#
#
# t = -46.62954536120224
# p = 0.0
# 유의미
# --------------------------------------------------------
#
# 변수 : 최근2주간 불편감일수
#
#
# t = -9.658434334684603
# p = 6.016173674603106e-22
# 유의미
# --------------------------------------------------------
#
# 변수 : 최근 1달간 와병일수
#
#
# t = -6.532035646479192
# p = 7.592448503537662e-11
# 유의미
# --------------------------------------------------------
#
# 변수 : 음주 시작 연령
#
#
# t = -14.231308731455302
# p = 7.893252833638888e-46
# 유의미
# --------------------------------------------------------
#
# 변수 : 주당 평균 근로시간
#
#
# t = -7.286945482128583
# p = 3.262078060594584e-13
# 유의미
# --------------------------------------------------------
#
# 변수 : 하루평균 흡연량
#
#
# t = -6.9563143379230645
# p = 3.800689821798677e-12
# 유의미
# --------------------------------------------------------
#
# 변수 : 걷기 지속 시간(시간)
#
#
# t = -1.8192584191818526
# p = 0.06888128309249505
# 무의미
# --------------------------------------------------------
#
# 변수 : 공복시간
#
#
# ...

# %% [markdown]
# ### 사용되지 않은 범주형 변수

# %%
non_cat
# Out:
# [{'DM4_dg': '골다공증 의사진단 여부'},
#  {'DJ6_dg': '부비동염 의사진단 여부'},
#  {'DH4_dg': '중이염 의사진단 여부'},
#  {'DH2_dg': '백내장 의사진단 여부'},
#  {'DH3_dg': '녹내장 의사진단 여부'},
#  {'BH1_1': '(성인) 건강검진 _본인부담종합'},
#  {'BH1_2': '(성인) 건강검진 _산업장특수1)'},
#  {'BH1_3': '(성인) 건강검진 _건강보험'},
#  {'BH1_8': '(성인) 건강검진 _무료건강검진'},
#  {'LQ3_sb': '최근 1년간 와병여부'},
#  {'EC_wh': '근로시간제'},
#  {'BS2_1': '흡연 시작연령'},
#  {'BS2_2': '매일 흡연 시작연령'},
#  {'BE3_71': '일_고강도 신체활동 여부'},
#  {'BE3_81': '일_중강도 신체활동 여부'},
#  {'BE3_91': '장소이동 신체활동 여부'},
#  {'BE3_75': '여가_고강도 신체활동 여부'},
#  {'BE3_85': '여가_중강도 신체활동 여부'},
#  {'BE9': '하루 60분 이상 신체활동 실천 일수'},
#  {'pa_aerobic': '유산소 신체활동 실천율'},
#  {'FS_MEAL': '하루 섭취 끼니 수'}]

# %% [markdown]
# ### 사용되지 않은 연속형 변수

# %%
non_cont
# Out:
# [{'LQ3_mn': '최근 1년간 와병일수'},
#  {'BD2_14': '한번에 마시는 음주량_잔'},
#  {'BP16_11': '주중 잠자리에 든 시각_시'},
#  {'BP16_13': '주중 일어난 시각_시'},
#  {'BP16_21': '주말 잠자리에 든 시각_시'},
#  {'BP16_23': '주말 일어난 시각_시'},
#  {'Total_slp_wk': '주중 하루 평균 수면시간'},
#  {'Total_slp_wd': '주말 하루 평균 수면시간'},
#  {'BE3_72': '일_고강도 신체활동 일수'},
#  {'BE3_73': '일_고강도 신체활동 시간(시간)'},
#  {'BE3_82': '일_중강도 신체활동 일수'},
#  {'BE3_83': '일_중강도 신체활동 시간(시간)'},
#  {'BE3_92': '장소이동 신체활동 일수'},
#  {'BE3_93': '장소이동 신체활동 시간(시간)'},
#  {'BE3_76': '여가_고강도 신체활동 일수'},
#  {'BE3_77': '여가_고강도 신체활동 시간(시간)'},
#  {'BE3_86': '여가_중강도 신체활동 일수'},
#  {'BE3_87': '여가_중강도 신체활동 시간(시간)'},
#  {'BE8_1': '평소 하루 앉아서 보내는 시간(시간)'}]
